# %%
pip install google_search_results
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
pip install serpapi
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-serp-api
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
pip install googlesearch-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import serpapi

# %%
params={
       'engine': "google_shopping_light",
       'q': "coughsyrup",
       'api_key': "52fc8d837bf67b1c01a02ab6c1a847411e2821441e5d2da3e526196b58a4e6a0"
}
search= serpapi.GoogleSearch(params)

# %%
results= search.get_dict()

# %%
results
# Out:
# {'search_metadata': {'id': '691095f869819d7b7a757c01',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/5038411950eceffc/691095f869819d7b7a757c01.json',
#   'created_at': '2025-11-09 13:24:08 UTC',
#   'processed_at': '2025-11-09 13:24:08 UTC',
#   'google_shopping_light_url': 'https://www.google.com/search?udm=28&q=coughsyrup&hl=en&gl=us',
#   'raw_html_file': 'https://serpapi.com/searches/5038411950eceffc/691095f869819d7b7a757c01.html',
#   'total_time_taken': 2.77},
#  'search_parameters': {'engine': 'google_shopping_light',
#   'q': 'coughsyrup',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'gl': 'us',
#   'device': 'desktop'},
#  'search_information': {'shopping_results_state': 'Showing results for exact spelling despite spelling suggestion',
#   'spelling_fix': 'cough syrup'},
#  'shopping_results': [{'position': 1,
#    'title': 'Robitussin Adult Maximum Strength Cough + Chest Congestion DM',
#    'product_id': '10240016944140390243',
# ...

# %%
shopping_results= results['shopping_results']

# %%
shopping_results[0].get('price')
# Out:
# '$15.99'

# %%
number= int(input("enter the number of option"))
# Out:
# enter the number of option 3

# %%
lowest_price= shopping_results[0].get('price')
lowest_price_index=0

# %%
for i in range(number):
          print(i)
          current_price= shopping_results[i].get("price")
          print("Title:",shopping_results[i].get("title"))
          print("Price:",shopping_results[i].get("price"))
          print("Source:",shopping_results[i].get("source"))
          if (current_price<lowest_price):
              lowest_price=current_price
              lowest_price_index=i
print("best option")
print("Title:",shopping_results[lowest_price_index].get("title"))
print("Price:",shopping_results[lowest_price_index].get("price"))
print("Source:",shopping_results[lowest_price_index].get("source"))
# Out:
# 0
# Title: Robitussin Adult Maximum Strength Cough + Chest Congestion DM
# Price: $15.99
# Source: Walgreens.com
# 1
# Title: Robitussin Maximum Strength Severe Multi-Symptom Cough Cold
# Price: $12.48
# Source: Walmart
# 2
# Title: Mucinex Fast-Max Maximum Strength Severe Congestion and Cough Liquid
# Price: $13.99
# Source: Target
# best option
# Title: Robitussin Maximum Strength Severe Multi-Symptom Cough Cold
# Price: $12.48
# Source: Walmart

# %% [markdown]
# #
